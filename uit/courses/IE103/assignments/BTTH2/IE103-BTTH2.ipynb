-- %% [markdown]
-- # BTTH 2 - IE103 - Nhom 02

-- %% [markdown]
-- ## Phần 1

-- %% [markdown]
-- - Use the correct database:

-- %%
USE "IE103-BTTH2";
-- Out:
-- Commands completed successfully.
-- Total execution time: 00:00:00.002
